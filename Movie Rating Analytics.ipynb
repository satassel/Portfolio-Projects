# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/asselsatayeva/Desktop/Python Programming Course'

# %%
os.chdir('/Users/asselsatayeva/Desktop/Python Programming Course')

# %%
movies=pd.read_csv('P4-Movie-Ratings.csv')

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.columns=['Film','Genre', 'CriticRating', 'AudienceRating','BudgetMillion','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillion   559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film=movies.Film.astype('category')
movies.Genre=movies.Genre.astype('category')
movies.Year=movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillion   559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillion
# count    559.000000      559.000000     559.000000
# mean      47.309481       58.744186      50.236136
# std       26.413091       16.826887      48.731817
# min        0.000000        0.000000       0.000000
# 25%       25.000000       47.000000      20.000000
# 50%       46.000000       58.000000      35.000000
# 75%       70.000000       72.000000      65.000000
# max       97.000000       96.000000     300.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
chart1=sns.jointplot(data=movies,x='CriticRating', y='AudienceRating')

# %%
chart1=sns.jointplot(data=movies,x='CriticRating', y='BudgetMillion', kind='hex')

# %%
#Histogram

# %%
chart2=sns.distplot(movies.CriticRating, bins=15)  #through seaborn

# %%
sns.set_style('darkgrid')   #through pyplot
chart3=plt.hist(movies.CriticRating, bins=15)

# %%
#Stacked Histogram

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies[movies.Genre=="Drama"].BudgetMillion
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillion, Length: 101, dtype: int64

# %%
for gen in movies.Genre.cat.categories:
   print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1=[]
mylabels=list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillion)
    mylabels.append(gen)
print(list1)
# Out:
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
#       ...
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: BudgetMillion, Length: 154, dtype: int64, 1      105
# 3       18
# 19     200
# 21      45
# 24      40
# 32      78
# 46      20
# 65      38
# 68     140
# 130     73
# 165     12
# 166    125
# 167    250
# 168    150
# 176     36
# 178    150
# 192     70
# 193     60
# 241     60
# 272     37
# 341     19
# 363     70
# 386    130
# 401    155
# 459     59
# 463     25
# 506     38
# 540    100
# 548     60
# Name: BudgetMillion, dtype: int64, 0       8
# 4      20
# 6      30
# 8      28
# 9       8
#        ..
# 552    80
# 553    22
# 554    50
# 555    18
# 558    80
# Name: BudgetMillion, Length: 172, dtype: int64, 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillion, Length: 101, dtype: int64, 7      32
# 12     35
# 20     40
# ...

# %%
plt.hist(list1, bins=15,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#KDE Plot

# %%
ch1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',hue='Genre',fit_reg=False)

# %%
ch2=sns.kdeplot(data=movies,x='CriticRating',y='AudienceRating', shade=True, shade_lowest=False,  fit_reg=False, cmap='Blues' )
ch3=sns.kdeplot(data=movies,x='CriticRating',y='AudienceRating',cmap='Blues' )

# %%
ch3=sns.kdeplot(data=movies,x='CriticRating',y='AudienceRating',cmap='Blues' )

# %%
#subplot

# %%
k1=sns.kdeplot(movies.BudgetMillion,movies.AudienceRating,color='Pink')

# %%
k2=sns.kdeplot(movies.BudgetMillion, movies.CriticRating, color='Orange')

# %%
f, axes=plt.subplots(1,2, figsize=(12,6),sharey=True,sharex=True)
k1=sns.kdeplot(movies.BudgetMillion,movies.AudienceRating,color='Pink', shade=True, cmap='autumn', ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillion, movies.CriticRating, color='Purple',shade=True, cmap='rainbow', ax=axes[1])
k1.set(xlim=(-50,250))
# Out:
# [(-50.0, 250.0)]

# %%
#Violinplot vs. Boxplot

# %%
z1=sns.violinplot(data=movies,x="Genre", y="CriticRating")

# %%
z2=sns.boxplot(data=movies,x="Genre", y="CriticRating")

# %%
z3=sns.violinplot(data=movies[movies.Genre=='Action'], x="Year", y='CriticRating', palette='twilight_shifted')

# %%
z4=sns.boxplot(data=movies[movies.Genre=='Action'], x="Year", y='CriticRating', palette='rainbow_r')

# %%
z5=sns.FacetGrid(movies,row='Genre',col='Year', hue='Genre')
z5=z5.map(plt.scatter,"AudienceRating","CriticRating")

# %%
z6=sns.FacetGrid(movies,row='Genre',col='Year', hue='Genre')
z6=z6.map(plt.hist,'BudgetMillion')

# %%
kws
# Out:
# {'s': 50, 'linewidth': 0.5, 'edgecolor': 'Black'}

# %%
z5=sns.FacetGrid(movies,row='Genre',col='Year', hue='Genre')
kws=dict(s=80, linewidth=1, edgecolor='Pink')
z5=z5.map(plt.scatter,"AudienceRating","CriticRating",**kws)

# %%
z5=sns.FacetGrid(movies,row='Genre',col='Year', hue='Genre')
kws=dict(s=80, linewidth=1, edgecolor='Pink')
z5=z5.map(plt.scatter,"AudienceRating","CriticRating",**kws)
z5.set(xlim=(0,100),ylim=(0,100))
for ax in z5.axes.flat:
    ax.plot((0,100),(0,100),ls='--')
z5.add_legend()
